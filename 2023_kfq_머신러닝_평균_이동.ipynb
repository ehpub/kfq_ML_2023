# %% [markdown]
# <a href="https://colab.research.google.com/github/ehpub/kfq_ML_2023/blob/main/2023_kfq_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%ED%8F%89%EA%B7%A0_%EC%9D%B4%EB%8F%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 강의 교재 : https://wikibook.co.kr/pymlrev2/

# %%
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x,y = make_blobs(n_samples = 200,
                 n_features=2,
                 centers = 3,
                 cluster_std = 0.8
                 )
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
model = MeanShift(bandwidth=0.8)
pred = model.fit_predict(x)
np.unique(pred,return_counts=True)
plt.scatter(x[:,0],x[:,1],c=pred)
for center in model.cluster_centers_:
  plt.plot(center[0],center[1],'ro')
plt.show()

# %%
model = MeanShift(bandwidth=1)
pred = model.fit_predict(x)
np.unique(pred,return_counts=True)
plt.scatter(x[:,0],x[:,1],c=pred)
for center in model.cluster_centers_:
  plt.plot(center[0],center[1],'ro')
plt.show()

# %%
model = MeanShift(bandwidth=1.5)
pred = model.fit_predict(x)
np.unique(pred,return_counts=True)
plt.scatter(x[:,0],x[:,1],c=pred)
for center in model.cluster_centers_:
  plt.plot(center[0],center[1],'ro')
plt.show()

# %%
from sklearn.cluster import estimate_bandwidth

# %%
estimate_bandwidth(x)
# Out:
# 2.312071323832261

# %%
model = MeanShift(bandwidth=2.3)
pred = model.fit_predict(x)
np.unique(pred,return_counts=True)
plt.scatter(x[:,0],x[:,1],c=pred)
for center in model.cluster_centers_:
  plt.plot(center[0],center[1],'ro')
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# %%
iris = load_iris()
data = iris.data
label = iris.target

# %%
pca = PCA(n_components=2)
pca.fit(data)
pca_data = pca.transform(data)

# %%
eb = estimate_bandwidth(pca_data)

# %%
model = MeanShift(bandwidth=eb)
pred = model.fit_predict(pca_data)

# %%
np.unique(pred,return_counts=True)
# Out:
# (array([0, 1]), array([99, 51]))

# %%
plt.scatter(pca_data[:,0],pca_data[:,1],c=pred)
plt.scatter(pca_data[:,0],pca_data[:,1],c=label,s=2.0)
plt.show()

# %%
model = MeanShift(bandwidth=0.77)
pred = model.fit_predict(pca_data)
print(np.unique(pred,return_counts=True))
plt.scatter(pca_data[:,0],pca_data[:,1],c=pred)
plt.scatter(pca_data[:,0],pca_data[:,1],c=label,s=2.0)
plt.show()
# Out:
# (array([0, 1, 2]), array([64, 51, 35]))
