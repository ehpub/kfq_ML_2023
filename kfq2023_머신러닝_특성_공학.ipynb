# %% [markdown]
# <a href="https://colab.research.google.com/github/ehpub/kfq_ML_2023/blob/main/kfq2023_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%ED%8A%B9%EC%84%B1_%EA%B3%B5%ED%95%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x_sample= np.array([[1,2]])
pf = PolynomialFeatures(degree=2,include_bias=False)
pf.fit(x_sample)
xt = pf.transform(x_sample)
xt
# Out:
# array([[1., 2., 1., 2., 4.]])

# %%
x2 = np.array([[3,4]])
xt = pf.transform(x2)
xt
# Out:
# array([[ 3.,  4.,  9., 12., 16.]])

# %%
x = np.array([[np.random.uniform(-10,10),
               np.random.uniform(-10,10)]
              for _ in range(100)] )
plt.plot(x[:,0],x[:,1],'r.')
plt.show()

# %%
x_1 = x[:,0]
x_2 = x[:,1]
y =2*(x_1**2)+3*(x_1*x_2)+4*x_1+2.3*x_2-3.5*(x_2**2)+7 + np.random.uniform(-100,100,size=(100))

# %%
plt.plot(x_1,y,'r.')
plt.show()

# %%
plt.plot(x_2,y,'r.')
plt.show()

# %%
xt = pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(xt,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train,y_train)
pred = model.predict(x_test)

# %%
plt.plot(y_test,'bo')
plt.plot(pred,'r.')
plt.show()

# %%
x_train2,x_test2,y_train2,y_test2 = train_test_split(x,y)
model2 = LinearRegression()
model2.fit(x_train2,y_train2)
pred2 = model2.predict(x_test2)

# %%
plt.plot(y_test2,'bo')
plt.plot(pred2,'r.')
plt.show()

# %%
model.score(x_test,y_test)
# Out:
# 0.8930285099797652

# %%
model2.score(x_test2,y_test2)
# Out:
# -0.21550267687471236

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pred)
# Out:
# 0.8930285099797652

# %%
r2_score(y_test2,pred2)
# Out:
# -0.21550267687471236

# %%
model.coef_, model.intercept_
# Out:
# (array([ 3.13693029,  3.06404145,  1.95488167,  3.0477301 , -3.5557003 ]),
#  3.0830487967432987)

# %%
y = 2*x_1 + 3*x_2**2 + 3*x_2**3 + np.random.uniform(-100,100,size=100)

# %%
plt.plot(x_1,y,'b.')
plt.show()

# %%
plt.plot(x_2,y,'b.')
plt.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)
model = LinearRegression()
model.fit(x_train,y_train)
pred = model.predict(x)

# %%
plt.plot(x_2, y,'bo')
plt.plot(x_2, pred,'r.')
plt.show()

# %%
model.score(x_train,y_train)
# Out:
# 0.8594206063947544

# %%
model.score(x_test,y_test)
# Out:
# 0.5356222843420979

# %%
pf = PolynomialFeatures(degree=3)
pf.fit(x)
xt = pf.transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(xt,y)
model = LinearRegression()
model.fit(x_train,y_train)
pred = model.predict(xt)

# %%
plt.plot(x_2, y,'bo')
plt.plot(x_2, pred,'r.')
plt.show()

# %%
model.score(x_train,y_train)
# Out:
# 0.9979930276057238

# %%
model.score(x_test,y_test)
# Out:
# 0.9952626656661642

# %%
model.score(xt,y)
# Out:
# 0.997539697011345

# %%
pf = PolynomialFeatures(degree=13)
pf.fit(x)
xt = pf.transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(xt,y)
model = LinearRegression()
model.fit(x_train,y_train)
pred = model.predict(xt)

# %%
plt.plot(x_2, y,'bo')
plt.plot(x_2, pred,'r.')
plt.show()

# %%
pred2 = model.predict(x_train)
plt.plot(x_train, y_train,'bo')
plt.plot(x_train, pred2,'r.')
plt.show()

# %%
model.score(x_train,y_train)
# Out:
# 0.999999977413685

# %%
model.score(x_test,y_test)
# Out:
# -136010715.18784586
